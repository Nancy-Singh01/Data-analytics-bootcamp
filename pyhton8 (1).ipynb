# %%
#Dictonary
import pandas as pd
data={
    'name': ['nancy','jjk','jk'],
    'age' : [18,20,5],
    'marks':[50,60,80]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     name  age  marks
# 0  nancy   18     50
# 1    jjk   20     60
# 2     jk    5     80

# %%
df= pd.DataFrame({'ID':[1,2],'name':['A','B']})
df1= pd.DataFrame({'ID':[1,2],'marks':[98,23]})
merged =pd.merge (df,df1,on='ID')
print(merged)
# Out:
#    ID name  marks
# 0   1    A     98
# 1   2    B     23

# %%
import pandas as pd

file_path = r'C:\Users\Lenovo\Downloads\archive\tmdb_5000_credits.csv'
df = pd.read_csv(file_path)

df_clean = df.dropna()

print("Null values dropped. Cleaned file saved.")
# Out:
# Null values dropped. Cleaned file saved.

# %%
import matplotlib.pyplot as plt

x=[1,2,3,10]
y=[5,6,7,3]
plt.plot(x,y,color='green' , linestyle='--',markerfacecolor='black')
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3]
y=[5,6,7]
plt.bar(x,y,color='purple')
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("x axis")

plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3]
y=[5,6,7]
plt.barh(x,y,color='green' ) 
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("x axis")

plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3]
y=[5,6,7]
plt.scatter(x,y,color='green' )
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("x axis")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
data = np.random.randn(1000)
x=[1,2,3]
y=[5,6,7]
plt.hist(data, bins=30, color='green', edgecolor='black')
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("x axis")

plt.show()

# %%
labels=['python','java','c++']
size=[50,25,25]
plt.pie(size,labels=labels ,autopct='%1.1f%%')
plt.title("pie chart")
plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\Lenovo\Downloads\archive\tmdb_5000_credits.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt


plt.bar(x,y,color='purple')
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("x axis")

plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\Lenovo\Downloads\archive\tmdb_5000_credits.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
subset = df[['title', 'movie_id']].head(10) 
plt.bar(subset['title'], subset['movie_id'], color='purple')
plt.title("Movie IDs by Title")
plt.xlabel("Movie Title")
plt.ylabel("ID")


plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\Lenovo\Downloads\archive\tmdb_5000_credits.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
subset = df[['title', 'movie_id']].head(10) 
plt.bar(subset['title'], subset['movie_id'], color='purple')
plt.title("Movie IDs by Title")
plt.xlabel("Movie Title")
plt.ylabel("ID")


plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\Lenovo\Downloads\archive\tmdb_5000_credits.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt


plt.bar(x,y,color='purple')
plt.title("line plot")
plt.xlabel("x axis")
plt.ylabel("x axis")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 df = pd.read_csv(file_path)
#       5 import matplotlib.pyplot as plt
# ----> 8 plt.bar(x,y,color='purple')
#       9 plt.title("line plot")
#      10 plt.xlabel("x axis")
#
# NameError: name 'x' is not defined
